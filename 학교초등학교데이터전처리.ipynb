# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/MYCOM/data/2022년도_안전교육 계획 및 실시현황(초)_서울특별시교육청.csv")

# %%
data.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '전체학급수', '전체학생수', '생활안전교육 시간(단위활동차시)-1학기',
#        '생활안전교육 시간(단위활동차시)-2학기', '생활안전교육 시간(단위활동차시)-합계',
#        '교통안전교육 시간(단위활동차시)-1학기', '교통안전교육 시간(단위활동차시)-2학기',
#        '교통안전교육 시간(단위활동차시)-합계', '폭력예방및신변보호교육 시간(단위활동차시)-1학기',
#        '폭력예방및신변보호교육 시간(단위활동차시)-2학기', '폭력예방및신변보호교육 시간(단위활동차시)-합계',
#        '약물중독예방교육 시간(단위활동차시) - 1학기 (2020년 이후)',
#        '약물중독예방교육 시간(단위활동차시) - 2학기 (2020년 이후)',
#        '약물중독예방교육 시간(단위활동차시) - 합계 (2020년 이후)',
#        '사이버중독예방교육 시간(단위활동차시) - 1학기 (2020, 2021, 2022년)',
#        '사이버중독예방교육 시간(단위활동차시) - 2학기 (2020, 2021, 2022년)',
#        '사이버중독예방교육 시간(단위활동차시) - 합계 (2020, 2021, 2022년)',
#        '재난안전교육 시간(단위활동차시)-1학기', '재난안전교육 시간(단위활동차시)-2학기',
#        '재난안전교육 시간(단위활동차시)-합계', '직업안전교육 시간(단위활동차시)-1학기',
#        '직업안전교육 시간(단위활동차시)-2학기', '직업안전교육 시간(단위활동차시)-합계',
#        '응급처치교육 시간(단위활동차시)-1학기', '응급처치교육 시간(단위활동차시)-2학기',
#        '응급처치교육 시간(단위활동차시)-합계'],
#       dtype='object')

# %%
data=data[['지역','학교명','전체학급수','전체학생수','생활안전교육 시간(단위활동차시)-합계','교통안전교육 시간(단위활동차시)-합계',
     '폭력예방및신변보호교육 시간(단위활동차시)-합계', '약물중독예방교육 시간(단위활동차시) - 합계 (2020년 이후)',
     '사이버중독예방교육 시간(단위활동차시) - 합계 (2020, 2021, 2022년)','재난안전교육 시간(단위활동차시)-합계',
     '직업안전교육 시간(단위활동차시)-합계','응급처치교육 시간(단위활동차시)-합계']]

# %%
data.head()
# Out:
#           지역       학교명  전체학급수   전체학생수  생활안전교육 시간(단위활동차시)-합계  \
# 0  서울특별시 강남구  서울개일초등학교     32  1004.0                  12.0
# 1  서울특별시 강남구  서울구룡초등학교     30   726.0                  11.0
# 2  서울특별시 강남구  서울논현초등학교     14   281.0                  12.0
# 3  서울특별시 강남구  서울대곡초등학교     47  1218.0                  10.0
# 4  서울특별시 강남구  서울대도초등학교     62  2129.0                  15.0
#
#    교통안전교육 시간(단위활동차시)-합계  폭력예방및신변보호교육 시간(단위활동차시)-합계  \
# 0                  11.0                        8.0
# 1                  10.0                        5.5
# 2                  11.0                        8.0
# 3                  10.0                        8.0
# 4                  15.0                       11.0
#
#    약물중독예방교육 시간(단위활동차시) - 합계 (2020년 이후)  \
# 0                                  5.0
# 1                                  2.0
# 2                                  5.0
# 3                                  4.0
# 4                                  5.0
#
# ...

# %%
#data[['지역','학교명','전체학급수','전체학생수','생활안전교육 시간(단위활동차시)-합계','교통안전교육 시간(단위활동차시)-합계',
#     '폭력예방및신변보호교육 시간(단위활동차시)-합계', '약물중독예방교육 시간(단위활동차시) - 합계 (2020년 이후)',
#     '사이버중독예방교육 시간(단위활동차시) - 합계 (2020, 2021, 2022년)','재난안전교육 시간(단위활동차시)-합계',
#    '직업안전교육 시간(단위활동차시)-합계','응급처치교육 시간(단위활동차시)-합계']]

new_cols=['구','학교명','전체학급수','전체학생수','생활안전교육시간','교통안전교육시간','폭력예방및신변보호교육시간','약물중독예방교육시간',
          '사이버중독예방교육시간','재난안전교육시간','직업안전교육시간','응급처치교육시간']
data.columns=new_cols
data.head()
# Out:
#            구       학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  \
# 0  서울특별시 강남구  서울개일초등학교     32  1004.0      12.0      11.0            8.0
# 1  서울특별시 강남구  서울구룡초등학교     30   726.0      11.0      10.0            5.5
# 2  서울특별시 강남구  서울논현초등학교     14   281.0      12.0      11.0            8.0
# 3  서울특별시 강남구  서울대곡초등학교     47  1218.0      10.0      10.0            8.0
# 4  서울특별시 강남구  서울대도초등학교     62  2129.0      15.0      15.0           11.0
#
#    약물중독예방교육시간  사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간
# 0         5.0          5.0       6.0       2.0       2.0
# 1         2.0          3.2       6.3       6.0       4.0
# 2         5.0          5.0       6.0       2.0       2.0
# 3         4.0          6.0       7.0       2.0       4.0
# 4         5.0          5.0      10.0       4.0       3.0

# %%
data.columns
# Out:
# Index(['구', '학교명', '전체학급수', '전체학생수', '생활안전교육시간', '교통안전교육시간', '폭력예방및신변보호교육시간',
#        '약물중독예방교육시간', '사이버중독예방교육시간', '재난안전교육시간', '직업안전교육시간', '응급처치교육시간'],
#       dtype='object')

# %%
data['구'].value_counts()
# Out:
# 서울특별시 노원구     42
# 서울특별시 송파구     41
# 서울특별시 강서구     35
# 서울특별시 강남구     31
# 서울특별시 은평구     30
# 서울특별시 양천구     30
# 서울특별시 성북구     29
# 서울특별시 강동구     27
# 서울특별시 구로구     26
# 서울특별시 중랑구     24
# 서울특별시 영등포구    23
# 서울특별시 서초구     23
# 서울특별시 도봉구     23
# 서울특별시 광진구     22
# 서울특별시 마포구     22
# 서울특별시 관악구     22
# 서울특별시 동작구     21
# 서울특별시 동대문구    21
# 서울특별시 성동구     21
# 서울특별시 서대문구    19
# 서울특별시 금천구     18
# 서울특별시 용산구     15
# 서울특별시 강북구     14
# 서울특별시 중구      12
# 서울특별시 종로구     12
# Name: 구, dtype: int64

# %%
df = {'주소': ['서울특별시 강남구', '서울특별시 노원구', '서울특별시 은평구', '서울특별시 중구']}
df = pd.DataFrame(df)

# '서울특별시 '를 제거하고 '구' 정보만 추출
df['구'] = df['주소'].str.replace('서울특별시 ', '')
df
# Out:
#           주소    구
# 0  서울특별시 강남구  강남구
# 1  서울특별시 노원구  노원구
# 2  서울특별시 은평구  은평구
# 3   서울특별시 중구   중구

# %%
data.head()
# Out:
#            구       학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  \
# 0  서울특별시 강남구  서울개일초등학교     32  1004.0      12.0      11.0            8.0
# 1  서울특별시 강남구  서울구룡초등학교     30   726.0      11.0      10.0            5.5
# 2  서울특별시 강남구  서울논현초등학교     14   281.0      12.0      11.0            8.0
# 3  서울특별시 강남구  서울대곡초등학교     47  1218.0      10.0      10.0            8.0
# 4  서울특별시 강남구  서울대도초등학교     62  2129.0      15.0      15.0           11.0
#
#    약물중독예방교육시간  사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간
# 0         5.0          5.0       6.0       2.0       2.0
# 1         2.0          3.2       6.3       6.0       4.0
# 2         5.0          5.0       6.0       2.0       2.0
# 3         4.0          6.0       7.0       2.0       4.0
# 4         5.0          5.0      10.0       4.0       3.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   구              603 non-null    object
#  1   학교명            603 non-null    object
#  2   전체학급수          603 non-null    int64
#  3   전체학생수          601 non-null    float64
#  4   생활안전교육시간       603 non-null    float64
#  5   교통안전교육시간       603 non-null    float64
#  6   폭력예방및신변보호교육시간  603 non-null    float64
#  7   약물중독예방교육시간     603 non-null    float64
#  8   사이버중독예방교육시간    603 non-null    float64
#  9   재난안전교육시간       603 non-null    float64
#  10  직업안전교육시간       603 non-null    float64
#  11  응급처치교육시간       603 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 56.7+ KB

# %%
data['구']
# Out:
# 0      서울특별시 강남구
# 1      서울특별시 강남구
# 2      서울특별시 강남구
# 3      서울특별시 강남구
# 4      서울특별시 강남구
#          ...
# 598    서울특별시 구로구
# 599    서울특별시 구로구
# 600    서울특별시 송파구
# 601    서울특별시 중랑구
# 602    서울특별시 강동구
# Name: 구, Length: 603, dtype: object

# %%
data['주소'] = data['구'].str.replace('서울특별시 ', '')
data['주소'].value_counts()
# Out:
# 노원구     42
# 송파구     41
# 강서구     35
# 강남구     31
# 은평구     30
# 양천구     30
# 성북구     29
# 강동구     27
# 구로구     26
# 중랑구     24
# 영등포구    23
# 서초구     23
# 도봉구     23
# 광진구     22
# 마포구     22
# 관악구     22
# 동작구     21
# 동대문구    21
# 성동구     21
# 서대문구    19
# 금천구     18
# 용산구     15
# 강북구     14
# 중구      12
# 종로구     12
# Name: 주소, dtype: int64

# %%
data.drop('구',inplace=True,axis=1)
data.head()
# Out:
#         학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0  서울개일초등학교     32  1004.0      12.0      11.0            8.0         5.0
# 1  서울구룡초등학교     30   726.0      11.0      10.0            5.5         2.0
# 2  서울논현초등학교     14   281.0      12.0      11.0            8.0         5.0
# 3  서울대곡초등학교     47  1218.0      10.0      10.0            8.0         4.0
# 4  서울대도초등학교     62  2129.0      15.0      15.0           11.0         5.0
#
#    사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간   주소
# 0          5.0       6.0       2.0       2.0  강남구
# 1          3.2       6.3       6.0       4.0  강남구
# 2          5.0       6.0       2.0       2.0  강남구
# 3          6.0       7.0       2.0       4.0  강남구
# 4          5.0      10.0       4.0       3.0  강남구

# %%
data['나라']='대한민국'
data['시']='서울특별시'

# %%
data.head()
# Out:
#         학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0  서울개일초등학교     32  1004.0      12.0      11.0            8.0         5.0
# 1  서울구룡초등학교     30   726.0      11.0      10.0            5.5         2.0
# 2  서울논현초등학교     14   281.0      12.0      11.0            8.0         5.0
# 3  서울대곡초등학교     47  1218.0      10.0      10.0            8.0         4.0
# 4  서울대도초등학교     62  2129.0      15.0      15.0           11.0         5.0
#
#    사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간   주소    나라      시
# 0          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시
# 1          3.2       6.3       6.0       4.0  강남구  대한민국  서울특별시
# 2          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시
# 3          6.0       7.0       2.0       4.0  강남구  대한민국  서울특별시
# 4          5.0      10.0       4.0       3.0  강남구  대한민국  서울특별시

# %%
data.isnull().sum()
# Out:
# 학교명              0
# 전체학급수            0
# 전체학생수            2
# 생활안전교육시간         0
# 교통안전교육시간         0
# 폭력예방및신변보호교육시간    0
# 약물중독예방교육시간       0
# 사이버중독예방교육시간      0
# 재난안전교육시간         0
# 직업안전교육시간         0
# 응급처치교육시간         0
# 주소               0
# 나라               0
# 시                0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# 학교명              0
# 전체학급수            0
# 전체학생수            0
# 생활안전교육시간         0
# 교통안전교육시간         0
# 폭력예방및신변보호교육시간    0
# 약물중독예방교육시간       0
# 사이버중독예방교육시간      0
# 재난안전교육시간         0
# 직업안전교육시간         0
# 응급처치교육시간         0
# 주소               0
# 나라               0
# 시                0
# dtype: int64

# %%
data.to_csv("C:/Users/MYCOM/data/안전교육(초)서울특별시2022.csv")

# %%
data.shape
# Out:
# (601, 14)

# %%
data.skew()
# Out:
# C:\Users\MYCOM\AppData\Local\Temp\ipykernel_23412\1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# 전체학급수             0.627072
# 전체학생수             1.012800
# 생활안전교육시간          9.942685
# 교통안전교육시간         10.591055
# 폭력예방및신변보호교육시간     3.178880
# 약물중독예방교육시간        4.112335
# 사이버중독예방교육시간       5.162586
# 재난안전교육시간          9.410620
# 직업안전교육시간          2.637844
# 응급처치교육시간          3.557735
# dtype: float64

# %% [markdown]
# 생활안전교육시간

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))  

# 첫 번째 그래프 그리기
ax1.hist(data['생활안전교육시간'],bins=20)

# 두 번째 그래프 그리기
ax2.boxplot(data['생활안전교육시간'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x295eeb441c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x295eeb44790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x295eeb2aeb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x295eeb44d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x295eeb53040>],
#  'means': []}

# %% [markdown]
# 교통안전교육시간

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))  

# 첫 번째 그래프 그리기
ax1.hist(data['교통안전교육시간'],bins=20)

# 두 번째 그래프 그리기
ax2.boxplot(data['교통안전교육시간'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x295eebf7610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x295eebf7bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x295eebf7340>],
#  'medians': [<matplotlib.lines.Line2D at 0x295eec07190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x295eec07460>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))  

# 첫 번째 그래프 그리기
ax1.hist(data['폭력예방및신변보호교육시간'],bins=20)

# 두 번째 그래프 그리기
ax2.boxplot(data['폭력예방및신변보호교육시간'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x295eece3f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x295eeeb14f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x295eece3c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x295eeeb1a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x295eeeb1d60>],
#  'means': []}

# %%
acc=pd.read_excel("C:/Users/MYCOM/data/schoolattack.xlsx")
acc=acc[acc['학교급']=='초등학교']
acc=acc[acc['지역']=='서울특별시']

# %%
acc.drop(['Unnamed: 0','구분'],axis=1,inplace=True)
acc.head()
# Out:
#             학교명     지역        교육청 설립유형   학교급 사고자구분 사고자성별 사고자학년       사고접수일  \
# 24042  서울전곡초등학교  서울특별시    동부교육지원청   공립  초등학교  일반학생     여   5학년  2020-11-04
# 24043  서울방현초등학교  서울특별시  강남서초교육지원청   공립  초등학교  일반학생     남   1학년  2020-11-27
# 24044  서울신현초등학교  서울특별시    동부교육지원청   공립  초등학교  일반학생     남   3학년  2020-02-18
# 24045  서울번동초등학교  서울특별시  성북강북교육지원청   공립  초등학교  일반학생     여   4학년  2020-06-11
# 24047  서울가주초등학교  서울특별시  강동송파교육지원청   공립  초등학교  일반학생     남   1학년  2020-03-06
#
#             사고발생일  ...    사고부위     사고형태  사고매개물    사고당시활동    나라 hour 오전/오후 min  \
# 24042  2017-05-24  ...    복합부위       기타     기타        기타  대한민국   13    오후  20
# 24043  2018-02-08  ...  치아(구강)  물리적힘 노출     기타     장난/놀이  대한민국   12    오후  10
# 24044  2018-05-23  ...  치아(구강)  사람과의 충돌     자연      구기운동  대한민국   14    오후  10
# 24045  2018-06-19  ...       손     미끄러짐  운동/놀이        기타  대한민국   11    오전   0
# 24047  2018-12-13  ...  머리(두부)      넘어짐     가구  식사/수면/휴식  대한민국    9    오전  20
#
#       사고발생 계절  사고발생월
# 24042       봄      5
# ...

# %%
acc.head()
# Out:
#             학교명     지역        교육청 설립유형   학교급 사고자구분 사고자성별 사고자학년       사고접수일  \
# 24042  서울전곡초등학교  서울특별시    동부교육지원청   공립  초등학교  일반학생     여   5학년  2020-11-04
# 24043  서울방현초등학교  서울특별시  강남서초교육지원청   공립  초등학교  일반학생     남   1학년  2020-11-27
# 24044  서울신현초등학교  서울특별시    동부교육지원청   공립  초등학교  일반학생     남   3학년  2020-02-18
# 24045  서울번동초등학교  서울특별시  성북강북교육지원청   공립  초등학교  일반학생     여   4학년  2020-06-11
# 24047  서울가주초등학교  서울특별시  강동송파교육지원청   공립  초등학교  일반학생     남   1학년  2020-03-06
#
#             사고발생일  ...    사고부위     사고형태  사고매개물    사고당시활동    나라 hour 오전/오후 min  \
# 24042  2017-05-24  ...    복합부위       기타     기타        기타  대한민국   13    오후  20
# 24043  2018-02-08  ...  치아(구강)  물리적힘 노출     기타     장난/놀이  대한민국   12    오후  10
# 24044  2018-05-23  ...  치아(구강)  사람과의 충돌     자연      구기운동  대한민국   14    오후  10
# 24045  2018-06-19  ...       손     미끄러짐  운동/놀이        기타  대한민국   11    오전   0
# 24047  2018-12-13  ...  머리(두부)      넘어짐     가구  식사/수면/휴식  대한민국    9    오전  20
#
#       사고발생 계절  사고발생월
# 24042       봄      5
# ...

# %%
acc_ele = acc.groupby('학교명')['설립유형'].size().to_frame()
acc_ele.rename(columns={'설립유형': '사고수'}, inplace=True)

# %%
acc_ele.head()
# Out:
#         사고수
# 학교명
# 경기초등학교    5
# 경복초등학교   22
# 경희초등학교   26
# 계성초등학교   10
# 광운초등학교   54

# %% [markdown]
# ## 안전교육시간&사고수합치기

# %%
acc_ele_safety = pd.merge(data,acc_ele, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_safety['사고수'] = acc_ele_safety['사고수'].fillna(0)
acc_ele_safety.head()
# Out:
#         학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0  서울개일초등학교   32.0  1004.0      12.0      11.0            8.0         5.0
# 1  서울구룡초등학교   30.0   726.0      11.0      10.0            5.5         2.0
# 2  서울논현초등학교   14.0   281.0      12.0      11.0            8.0         5.0
# 3  서울대곡초등학교   47.0  1218.0      10.0      10.0            8.0         4.0
# 4  서울대도초등학교   62.0  2129.0      15.0      15.0           11.0         5.0
#
#    사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간   주소    나라      시   사고수
# 0          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시  18.0
# 1          3.2       6.3       6.0       4.0  강남구  대한민국  서울특별시  33.0
# 2          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시   6.0
# 3          6.0       7.0       2.0       4.0  강남구  대한민국  서울특별시  36.0
# 4          5.0      10.0       4.0       3.0  강남구  대한민국  서울특별시  50.0

# %%
acc_ele_safety.columns
# Out:
# Index(['학교명', '전체학급수', '전체학생수', '생활안전교육시간', '교통안전교육시간', '폭력예방및신변보호교육시간',
#        '약물중독예방교육시간', '사이버중독예방교육시간', '재난안전교육시간', '직업안전교육시간', '응급처치교육시간', '주소',
#        '나라', '시', '사고수'],
#       dtype='object')

# %%
acc_ele_safety.isnull().sum()
# Out:
# 학교명              0
# 전체학급수            6
# 전체학생수            6
# 생활안전교육시간         6
# 교통안전교육시간         6
# 폭력예방및신변보호교육시간    6
# 약물중독예방교육시간       6
# 사이버중독예방교육시간      6
# 재난안전교육시간         6
# 직업안전교육시간         6
# 응급처치교육시간         6
# 주소               6
# 나라               6
# 시                6
# 사고수              0
# dtype: int64

# %%
acc_ele_safety.dropna(inplace=True)
acc_ele_safety.isnull().sum()
# Out:
# 학교명              0
# 전체학급수            0
# 전체학생수            0
# 생활안전교육시간         0
# 교통안전교육시간         0
# 폭력예방및신변보호교육시간    0
# 약물중독예방교육시간       0
# 사이버중독예방교육시간      0
# 재난안전교육시간         0
# 직업안전교육시간         0
# 응급처치교육시간         0
# 주소               0
# 나라               0
# 시                0
# 사고수              0
# dtype: int64

# %%
acc_ele_safety.head()
# Out:
#         학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0  서울개일초등학교   32.0  1004.0      12.0      11.0            8.0         5.0
# 1  서울구룡초등학교   30.0   726.0      11.0      10.0            5.5         2.0
# 2  서울논현초등학교   14.0   281.0      12.0      11.0            8.0         5.0
# 3  서울대곡초등학교   47.0  1218.0      10.0      10.0            8.0         4.0
# 4  서울대도초등학교   62.0  2129.0      15.0      15.0           11.0         5.0
#
#    사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간   주소    나라      시   사고수
# 0          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시  18.0
# 1          3.2       6.3       6.0       4.0  강남구  대한민국  서울특별시  33.0
# 2          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시   6.0
# 3          6.0       7.0       2.0       4.0  강남구  대한민국  서울특별시  36.0
# 4          5.0      10.0       4.0       3.0  강남구  대한민국  서울특별시  50.0

# %%
acc_ele_safety.groupby('주소')['사고수'].sum()
# Out:
# 주소
# 강남구     750.0
# 강동구     789.0
# 강북구     352.0
# 강서구     829.0
# 관악구     402.0
# 광진구     439.0
# 구로구     669.0
# 금천구     304.0
# 노원구     966.0
# 도봉구     556.0
# 동대문구    519.0
# 동작구     518.0
# 마포구     431.0
# 서대문구    457.0
# 서초구     623.0
# 성동구     429.0
# 성북구     680.0
# 송파구     799.0
# 양천구     698.0
# 영등포구    432.0
# 용산구     307.0
# 은평구     711.0
# 종로구     152.0
# 중구      177.0
# 중랑구     644.0
# Name: 사고수, dtype: float64

# %%
import seaborn as sns
sns.heatmap(acc_ele_safety.corr())
# Out:
# <AxesSubplot:>

# %%
acc_ele_safety.corr()['사고수']
# 전체학생수, 전체학급수와 상관관계가 높음
# Out:
# 전체학급수            0.596134
# 전체학생수            0.596365
# 생활안전교육시간        -0.040269
# 교통안전교육시간        -0.036580
# 폭력예방및신변보호교육시간    0.027225
# 약물중독예방교육시간      -0.022232
# 사이버중독예방교육시간     -0.055638
# 재난안전교육시간        -0.023044
# 직업안전교육시간        -0.049165
# 응급처치교육시간        -0.032852
# 사고수              1.000000
# Name: 사고수, dtype: float64

# %%
plt.hist(acc_ele_safety['사고수'],bins=30)
# Out:
# (array([ 6., 24., 62., 59., 75., 80., 52., 76., 34., 33., 26., 16., 16.,
#         15.,  9.,  5.,  3.,  0.,  3.,  0.,  2.,  0.,  1.,  1.,  1.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([  0. ,   3.4,   6.8,  10.2,  13.6,  17. ,  20.4,  23.8,  27.2,
#          30.6,  34. ,  37.4,  40.8,  44.2,  47.6,  51. ,  54.4,  57.8,
#          61.2,  64.6,  68. ,  71.4,  74.8,  78.2,  81.6,  85. ,  88.4,
#          91.8,  95.2,  98.6, 102. ]),
#  <BarContainer object of 30 artists>)

# %%
acc_ele_safety['학급당평균학생수']=acc_ele_safety['전체학생수']/acc_ele_safety['전체학급수']
acc_ele_safety
# Out:
#            학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0     서울개일초등학교   32.0  1004.0      12.0      11.0            8.0         5.0
# 1     서울구룡초등학교   30.0   726.0      11.0      10.0            5.5         2.0
# 2     서울논현초등학교   14.0   281.0      12.0      11.0            8.0         5.0
# 3     서울대곡초등학교   47.0  1218.0      10.0      10.0            8.0         4.0
# 4     서울대도초등학교   62.0  2129.0      15.0      15.0           11.0         5.0
# ..         ...    ...     ...       ...       ...            ...         ...
# 596  서울금나래초등학교   41.0   890.0      12.0      11.0            8.0         4.0
# 597  서울하늘숲초등학교   33.0   647.0      12.0      11.0            8.0         5.0
# 598   서울항동초등학교   43.0   995.0      12.0       9.3            7.7         3.3
# 599  서울해누리초등학교   25.0   586.0      12.0      11.0            8.0         8.0
# 600   서울강빛초등학교   31.0   485.0      12.0      10.0            5.0         3.0
#
# ...

# %%
data.head()
# Out:
#         학교명  전체학급수   전체학생수  생활안전교육시간  교통안전교육시간  폭력예방및신변보호교육시간  약물중독예방교육시간  \
# 0  서울개일초등학교     32  1004.0      12.0      11.0            8.0         5.0
# 1  서울구룡초등학교     30   726.0      11.0      10.0            5.5         2.0
# 2  서울논현초등학교     14   281.0      12.0      11.0            8.0         5.0
# 3  서울대곡초등학교     47  1218.0      10.0      10.0            8.0         4.0
# 4  서울대도초등학교     62  2129.0      15.0      15.0           11.0         5.0
#
#    사이버중독예방교육시간  재난안전교육시간  직업안전교육시간  응급처치교육시간   주소    나라      시
# 0          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시
# 1          3.2       6.3       6.0       4.0  강남구  대한민국  서울특별시
# 2          5.0       6.0       2.0       2.0  강남구  대한민국  서울특별시
# 3          6.0       7.0       2.0       4.0  강남구  대한민국  서울특별시
# 4          5.0      10.0       4.0       3.0  강남구  대한민국  서울특별시

# %% [markdown]
# ## 방과후학교

# %%
data2=pd.read_csv("C:/Users/MYCOM/data/2022년도_방과후학교 운영 계획 및 운영ㆍ지원현황(초)_서울특별시교육청.csv")
data2.head()
# Out:
#       시도교육청           지역교육청         지역   정보공시 학교코드       학교명  학교급코드 설립구분 제외여부  \
# 0  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000738  서울개일초등학교      2   공립    N
# 1  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000741  서울구룡초등학교      2   공립    N
# 2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000742  서울논현초등학교      2   공립    N
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000743  서울대곡초등학교      2   공립    N
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000744  서울대도초등학교      2   공립    N
#
#    제외사유  교과프로그램수  ...  초등돌봄교실 저녁돌봄참여학생수  초등돌봄교실방과후학교 연계형돌봄운영교실수  \
# 0   NaN        6  ...                 0                       0
# 1   NaN       10  ...                 0                       1
# 2   NaN        7  ...                 1                       0
# 3   NaN       15  ...                 4                       0
# 4   NaN        6  ...                 0                       1
#
#    초등돌봄교실방과후학교 연계형돌봄참여학생수  초등돌봄참여학생중 특수교육대상학생수  특수학교종일반 학급수  특수학교종일반 참여학생수  \
# ...

# %%
data2.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '교과프로그램수', '교과수강학생수', '특기적성프로그램수', '특기적성수강학생수', '프로그램수(계)',
#        '수강학생수(계)', '방과후학교참여학생수', '초등돌봄교실 오후돌봄운영교실수', '초등돌봄교실 오후돌봄참여학생수',
#        '초등돌봄교실 저녁돌봄운영교실수', '초등돌봄교실 저녁돌봄참여학생수', '초등돌봄교실방과후학교 연계형돌봄운영교실수',
#        '초등돌봄교실방과후학교 연계형돌봄참여학생수', '초등돌봄참여학생중 특수교육대상학생수', '특수학교종일반 학급수',
#        '특수학교종일반 참여학생수', '방과후학교 수익자부담금액', '방과후학교 수익자부담외지원금액', '초등돌봄교실 수익자부담금액',
#        '초등돌봄교실 수익자부담외지원금액'],
#       dtype='object')

# %%
data2=data2[['지역','학교명','교과프로그램수','교과수강학생수','프로그램수(계)','수강학생수(계)','방과후학교참여학생수',
            '초등돌봄교실 오후돌봄운영교실수', '초등돌봄교실 오후돌봄참여학생수',
       '초등돌봄교실 저녁돌봄운영교실수', '초등돌봄교실 저녁돌봄참여학생수', '초등돌봄교실방과후학교 연계형돌봄운영교실수',
       '초등돌봄교실방과후학교 연계형돌봄참여학생수']]
data2.head()
# Out:
#           지역       학교명  교과프로그램수  교과수강학생수  프로그램수(계)  수강학생수(계)  방과후학교참여학생수  \
# 0  서울특별시 강남구  서울개일초등학교        6       62        44       546         257
# 1  서울특별시 강남구  서울구룡초등학교       10      126        52       727         359
# 2  서울특별시 강남구  서울논현초등학교        7      133        20       519         175
# 3  서울특별시 강남구  서울대곡초등학교       15      364        50      1239        1239
# 4  서울특별시 강남구  서울대도초등학교        6      211        34      1357         942
#
#    초등돌봄교실 오후돌봄운영교실수  초등돌봄교실 오후돌봄참여학생수  초등돌봄교실 저녁돌봄운영교실수  초등돌봄교실 저녁돌봄참여학생수  \
# 0                 2                50                 0                 0
# 1                 4                68                 0                 0
# 2                 4                62                 1                 1
# 3                20                50                 1                 4
# 4                 1                28                 0                 0
#
#    초등돌봄교실방과후학교 연계형돌봄운영교실수  초등돌봄교실방과후학교 연계형돌봄참여학생수
# ...

# %%
acc_ele_after = pd.merge(data2,acc_ele, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_after['사고수'] = acc_ele_after['사고수'].fillna(0)
acc_ele_after.head()
# Out:
#           지역       학교명  교과프로그램수  교과수강학생수  프로그램수(계)  수강학생수(계)  방과후학교참여학생수  \
# 0  서울특별시 강남구  서울개일초등학교      6.0     62.0      44.0     546.0       257.0
# 1  서울특별시 강남구  서울구룡초등학교     10.0    126.0      52.0     727.0       359.0
# 2  서울특별시 강남구  서울논현초등학교      7.0    133.0      20.0     519.0       175.0
# 3  서울특별시 강남구  서울대곡초등학교     15.0    364.0      50.0    1239.0      1239.0
# 4  서울특별시 강남구  서울대도초등학교      6.0    211.0      34.0    1357.0       942.0
#
#    초등돌봄교실 오후돌봄운영교실수  초등돌봄교실 오후돌봄참여학생수  초등돌봄교실 저녁돌봄운영교실수  초등돌봄교실 저녁돌봄참여학생수  \
# 0               2.0              50.0               0.0               0.0
# 1               4.0              68.0               0.0               0.0
# 2               4.0              62.0               1.0               1.0
# 3              20.0              50.0               1.0               4.0
# 4               1.0              28.0               0.0               0.0
#
#    초등돌봄교실방과후학교 연계형돌봄운영교실수  초등돌봄교실방과후학교 연계형돌봄참여학생수   사고수
# ...

# %%
acc_ele_after.dropna(inplace=True)
acc_ele_after.isnull().sum()
# Out:
# 지역                        0
# 학교명                       0
# 교과프로그램수                   0
# 교과수강학생수                   0
# 프로그램수(계)                  0
# 수강학생수(계)                  0
# 방과후학교참여학생수                0
# 초등돌봄교실 오후돌봄운영교실수          0
# 초등돌봄교실 오후돌봄참여학생수          0
# 초등돌봄교실 저녁돌봄운영교실수          0
# 초등돌봄교실 저녁돌봄참여학생수          0
# 초등돌봄교실방과후학교 연계형돌봄운영교실수    0
# 초등돌봄교실방과후학교 연계형돌봄참여학생수    0
# 사고수                       0
# dtype: int64

# %%
acc_ele_after.corr()['사고수']
# Out:
# 교과프로그램수                   0.187247
# 교과수강학생수                   0.220263
# 프로그램수(계)                  0.296190
# 수강학생수(계)                  0.376937
# 방과후학교참여학생수                0.458344
# 초등돌봄교실 오후돌봄운영교실수          0.308455
# 초등돌봄교실 오후돌봄참여학생수          0.366085
# 초등돌봄교실 저녁돌봄운영교실수         -0.031915
# 초등돌봄교실 저녁돌봄참여학생수          0.022283
# 초등돌봄교실방과후학교 연계형돌봄운영교실수    0.160693
# 초등돌봄교실방과후학교 연계형돌봄참여학생수    0.219707
# 사고수                       1.000000
# Name: 사고수, dtype: float64

# %%
sns.heatmap(acc_ele_after.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 급식

# %%
data3=pd.read_csv("C:/Users/MYCOM/data/2022년도_급식 실시 현황(초)_서울특별시교육청.csv",encoding='cp949')
data3.head()
# Out:
#       시도교육청           지역교육청         지역   정보공시 학교코드       학교명  학교급코드 설립구분 제외여부  \
# 0  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000738  서울개일초등학교      2   공립    N
# 1  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000741  서울구룡초등학교      2   공립    N
# 2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000742  서울논현초등학교      2   공립    N
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000743  서울대곡초등학교      2   공립    N
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000744  서울대도초등학교      2   공립    N
#
#   제외사유 운영방식 - 급식종류  ...   전체학생수   급식학생수   급식비율  급식담당인력(명) - 영양(교)사  \
# 0  NaN          직영  ...  1078.0   780.0   72.4                 1.0
# 1  NaN          직영  ...   745.0   745.0  100.0                 1.0
# 2  NaN          직영  ...   266.0   266.0  100.0                 1.0
# 3  NaN          직영  ...  1209.0  1209.0  100.0                 1.0
# 4  NaN          직영  ...  2025.0  2027.0  100.1                 1.0
#
#    급식담당인력(명) - 조리사  급식담당인력(명) - 조리원  배식장소 - 배식장소(식당)  배식장소 - 배식장소(교실)  \
# ...

# %%
data3.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '운영방식 - 급식종류', '운영방식 - 직영급식', '운영방식 - 전부위탁(업체명)',
#        '운영방식 - 일부위탁(업체명)', '전체학생수', '급식학생수', '급식비율', '급식담당인력(명) - 영양(교)사',
#        '급식담당인력(명) - 조리사', '급식담당인력(명) - 조리원', '배식장소 - 배식장소(식당)',
#        '배식장소 - 배식장소(교실)', '배식장소 - 배식장소(식당+교실)', '배식장소 - 배식장소(기타)'],
#       dtype='object')

# %%
data3=data3[['지역','학교명','전체학생수','급식학생수','급식비율','급식담당인력(명) - 영양(교)사',
       '급식담당인력(명) - 조리사', '급식담당인력(명) - 조리원', '배식장소 - 배식장소(식당)',
       '배식장소 - 배식장소(교실)', '배식장소 - 배식장소(식당+교실)']]
data3.loc[data3['배식장소 - 배식장소(식당+교실)']==1,'배식장소 - 배식장소(식당)']=1
data3.loc[data3['배식장소 - 배식장소(식당+교실)']==1,'배식장소 - 배식장소(교실)']=1
data3.head()
# Out:
#           지역       학교명   전체학생수   급식학생수   급식비율  급식담당인력(명) - 영양(교)사  \
# 0  서울특별시 강남구  서울개일초등학교  1078.0   780.0   72.4                 1.0
# 1  서울특별시 강남구  서울구룡초등학교   745.0   745.0  100.0                 1.0
# 2  서울특별시 강남구  서울논현초등학교   266.0   266.0  100.0                 1.0
# 3  서울특별시 강남구  서울대곡초등학교  1209.0  1209.0  100.0                 1.0
# 4  서울특별시 강남구  서울대도초등학교  2025.0  2027.0  100.1                 1.0
#
#    급식담당인력(명) - 조리사  급식담당인력(명) - 조리원  배식장소 - 배식장소(식당)  배식장소 - 배식장소(교실)  \
# 0              1.0              5.0                1                0
# 1              1.0              4.0                1                0
# 2              1.0              3.0                1                0
# 3              1.0              7.0                1                0
# 4              1.0             12.0                0                1
#
#    배식장소 - 배식장소(식당+교실)
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
data3.drop('배식장소 - 배식장소(식당+교실)',inplace=True,axis=1)

# %%
data3.dropna(inplace=True)
data3.isnull().sum()
# Out:
# 지역                    0
# 학교명                   0
# 전체학생수                 0
# 급식학생수                 0
# 급식비율                  0
# 급식담당인력(명) - 영양(교)사    0
# 급식담당인력(명) - 조리사       0
# 급식담당인력(명) - 조리원       0
# 배식장소 - 배식장소(식당)       0
# 배식장소 - 배식장소(교실)       0
# dtype: int64

# %% [markdown]
# ## 급식이랑 사고수 데이터 합치기

# %%
acc_ele_lunch = pd.merge(data3,acc_ele, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_lunch['사고수'] = acc_ele_lunch['사고수'].fillna(0)
acc_ele_lunch.head()
# Out:
#           지역       학교명   전체학생수   급식학생수   급식비율  급식담당인력(명) - 영양(교)사  \
# 0  서울특별시 강남구  서울개일초등학교  1078.0   780.0   72.4                 1.0
# 1  서울특별시 강남구  서울구룡초등학교   745.0   745.0  100.0                 1.0
# 2  서울특별시 강남구  서울논현초등학교   266.0   266.0  100.0                 1.0
# 3  서울특별시 강남구  서울대곡초등학교  1209.0  1209.0  100.0                 1.0
# 4  서울특별시 강남구  서울대도초등학교  2025.0  2027.0  100.1                 1.0
#
#    급식담당인력(명) - 조리사  급식담당인력(명) - 조리원  배식장소 - 배식장소(식당)  배식장소 - 배식장소(교실)   사고수
# 0              1.0              5.0              1.0              0.0  18.0
# 1              1.0              4.0              1.0              0.0  33.0
# 2              1.0              3.0              1.0              0.0   6.0
# 3              1.0              7.0              1.0              0.0  36.0
# 4              1.0             12.0              0.0              1.0  50.0

# %%
acc_ele_lunch.corr()['사고수']
# Out:
# 전체학생수                 0.597543
# 급식학생수                 0.598712
# 급식비율                  0.003517
# 급식담당인력(명) - 영양(교)사   -0.010962
# 급식담당인력(명) - 조리사       0.028461
# 급식담당인력(명) - 조리원       0.573767
# 배식장소 - 배식장소(식당)       0.072541
# 배식장소 - 배식장소(교실)      -0.051605
# 사고수                   1.000000
# Name: 사고수, dtype: float64

# %%
sns.heatmap(acc_ele_lunch.corr())
# Out:
# C:\Users\MYCOM\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# C:\Users\MYCOM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 전체 급식 데이터

# %%
data4=pd.read_excel("C:/Users/MYCOM/data/2022년_ 급식실시현황(초)_전체.xlsx")
data4.head()
# Out:
#       시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드  \
# 0     시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드
# 1  서울특별시교육청             교육부  서울특별시 서초구    S000003511    서울교육대학교부설초등학교     02
# 2  서울특별시교육청             교육부  서울특별시 종로구    S000003563  서울대학교사범대학부설초등학교     02
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구    S010000738         서울개일초등학교     02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구    S010000741         서울구룡초등학교     02
#
#    설립구분  제외여부  제외사유  운영방식  ...  전체 학생수  급식 학생수   급식비율 급식담당인력(명) 급식담당인력(명).1  \
# 0  설립구분  제외여부  제외사유  급식종류  ...  전체 학생수  급식 학생수   급식비율    영양(교)사         조리사
# 1    국립     N   NaN    직영  ...   612.0   612.0  100.0       1.0         1.0
# 2    국립     N   NaN    직영  ...   613.0   612.0   99.8       1.0         1.0
# 3    공립     N   NaN    직영  ...  1078.0   780.0   72.4       1.0         1.0
# 4    공립     N   NaN    직영  ...   745.0   745.0  100.0       1.0         1.0
#
# ...

# %%
data4.set_axis(data4.iloc[0], axis=1, inplace=True)
data4 = data4[1:]
data4.head()
# Out:
# 0     시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명 학교급코드  \
# 1  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교    02
# 2  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교    02
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교    02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교    02
# 5  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교    02
#
# 0 설립구분 제외여부 제외사유 급식종류  ...  전체 학생수 급식 학생수   급식비율 영양(교)사  조리사  조리원 배식장소(식당)  \
# 1   국립    N  NaN   직영  ...   612.0  612.0  100.0    1.0  1.0  3.0        1
# 2   국립    N  NaN   직영  ...   613.0  612.0   99.8    1.0  1.0  4.0      NaN
# 3   공립    N  NaN   직영  ...  1078.0  780.0   72.4    1.0  1.0  5.0        1
# 4   공립    N  NaN   직영  ...   745.0  745.0  100.0    1.0  1.0  4.0        1
# 5   공립    N  NaN   직영  ...   266.0  266.0  100.0    1.0  1.0  3.0        1
#
# 0 배식장소(교실) 배식장소(식당+교실) 배식장소(기타)
# ...

# %%
data4.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 \n 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '급식종류', '직영급식', '전부위탁(업체명)', '일부위탁(업체명)', '전체 학생수', '급식 학생수',
#        '급식비율', '영양(교)사', '조리사', '조리원', '배식장소(식당)', '배식장소(교실)', '배식장소(식당+교실)',
#        '배식장소(기타)'],
#       dtype='object', name=0)

# %%
data4=data4[['시도교육청','지역','학교명','전체 학생수','급식 학생수','급식비율','영양(교)사',
       '조리사', '조리원', '배식장소(식당)',
       '배식장소(교실)', '배식장소(식당+교실)']]
data4.loc[data4['배식장소(식당+교실)']==1,'배식장소(식당)']=1
data4.loc[data4['배식장소(식당+교실)']==1,'배식장소(교실)']=1
data4.head()
# Out:
# 0     시도교육청         지역              학교명  전체 학생수 급식 학생수   급식비율 영양(교)사  조리사  \
# 1  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   612.0  612.0  100.0    1.0  1.0
# 2  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   613.0  612.0   99.8    1.0  1.0
# 3  서울특별시교육청  서울특별시 강남구         서울개일초등학교  1078.0  780.0   72.4    1.0  1.0
# 4  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   745.0  745.0  100.0    1.0  1.0
# 5  서울특별시교육청  서울특별시 강남구         서울논현초등학교   266.0  266.0  100.0    1.0  1.0
#
# 0  조리원 배식장소(식당) 배식장소(교실) 배식장소(식당+교실)
# 1  3.0        1      NaN         NaN
# 2  4.0        1        1           1
# 3  5.0        1      NaN         NaN
# 4  4.0        1      NaN         NaN
# 5  3.0        1      NaN         NaN

# %%
data4['배식장소(식당)'].fillna(0,inplace=True)
data4['배식장소(교실)'].fillna(0,inplace=True)
data4['배식장소(식당+교실)'].fillna(0,inplace=True)
data4.head()
# Out:
# 0     시도교육청         지역              학교명  전체 학생수 급식 학생수   급식비율 영양(교)사  조리사  \
# 1  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   612.0  612.0  100.0    1.0  1.0
# 2  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   613.0  612.0   99.8    1.0  1.0
# 3  서울특별시교육청  서울특별시 강남구         서울개일초등학교  1078.0  780.0   72.4    1.0  1.0
# 4  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   745.0  745.0  100.0    1.0  1.0
# 5  서울특별시교육청  서울특별시 강남구         서울논현초등학교   266.0  266.0  100.0    1.0  1.0
#
# 0  조리원  배식장소(식당)  배식장소(교실)  배식장소(식당+교실)
# 1  3.0         1         0            0
# 2  4.0         1         1            1
# 3  5.0         1         0            0
# 4  4.0         1         0            0
# 5  3.0         1         0            0

# %%
acc2=pd.read_excel("C:/Users/MYCOM/data/schoolattack.xlsx")
acc2=acc2[acc2['학교급']=='초등학교']

# %%
data4.isnull().sum()
# Out:
# 0
# 시도교육청           0
# 지역             25
# 학교명             0
# 전체 학생수         12
# 급식 학생수         12
# 급식비율            0
# 영양(교)사         12
# 조리사            12
# 조리원            12
# 배식장소(식당)        0
# 배식장소(교실)        0
# 배식장소(식당+교실)     0
# dtype: int64

# %%
data4.dropna(inplace=True)

# %%
data4.isnull().sum()
# Out:
# 0
# 시도교육청          0
# 지역             0
# 학교명            0
# 전체 학생수         0
# 급식 학생수         0
# 급식비율           0
# 영양(교)사         0
# 조리사            0
# 조리원            0
# 배식장소(식당)       0
# 배식장소(교실)       0
# 배식장소(식당+교실)    0
# dtype: int64

# %%
acc_ele2 = acc2.groupby('학교명')['설립유형'].size().to_frame()
acc_ele2.rename(columns={'설립유형': '사고수'}, inplace=True)
acc_ele2.head()
# Out:
#              사고수
# 학교명
# 가경초등학교        15
# 가고파초등학교       48
# 가곡초등학교        31
# 가곡초등학교대곡분교장    4
# 가곡초등학교보발분교장    1

# %%
print(acc.shape)
print(acc2.shape)
print(acc_ele.shape)
print(acc_ele2.shape)
# Out:
# (13720, 24)
# (95033, 26)
# (606, 1)
# (5042, 1)

# %%
acc_ele_lunch2 = pd.merge(data4,acc_ele2, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_lunch2['사고수'] = acc_ele_lunch2['사고수'].fillna(0)
acc_ele_lunch2.head()
# Out:
#       시도교육청         지역              학교명  전체 학생수 급식 학생수   급식비율 영양(교)사  조리사  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   612.0  612.0  100.0    1.0  1.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   613.0  612.0   99.8    1.0  1.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교  1078.0  780.0   72.4    1.0  1.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   745.0  745.0  100.0    1.0  1.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교   266.0  266.0  100.0    1.0  1.0
#
#    조리원  배식장소(식당)  배식장소(교실)  배식장소(식당+교실)   사고수
# 0  3.0       1.0       0.0          0.0  36.0
# 1  4.0       1.0       1.0          1.0  21.0
# 2  5.0       1.0       0.0          0.0  18.0
# 3  4.0       1.0       0.0          0.0  33.0
# 4  3.0       1.0       0.0          0.0   6.0

# %%
acc_ele_lunch2[['전체 학생수','급식 학생수','급식비율','영양(교)사','조리사','조리원']]=acc_ele_lunch2[['전체 학생수','급식 학생수','급식비율','영양(교)사','조리사','조리원']].astype(float)
acc_ele_lunch2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6379 entries, 0 to 6378
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시도교육청        6272 non-null   object
#  1   지역           6272 non-null   object
#  2   학교명          6379 non-null   object
#  3   전체 학생수       6272 non-null   float64
#  4   급식 학생수       6272 non-null   float64
#  5   급식비율         6272 non-null   float64
#  6   영양(교)사       6272 non-null   float64
#  7   조리사          6272 non-null   float64
#  8   조리원          6272 non-null   float64
#  9   배식장소(식당)     6272 non-null   float64
#  10  배식장소(교실)     6272 non-null   float64
#  11  배식장소(식당+교실)  6272 non-null   float64
#  12  사고수          6379 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 697.7+ KB

# %%
acc_ele_lunch2.drop('배식장소(식당+교실)',inplace=True,axis=1)

# %%
acc_ele_lunch2.corr()['사고수']
# Out:
# 전체 학생수      0.391563
# 급식 학생수      0.392108
# 급식비율        0.031365
# 영양(교)사      0.148373
# 조리사         0.127177
# 조리원         0.387774
# 배식장소(식당)   -0.013366
# 배식장소(교실)    0.045026
# 사고수         1.000000
# Name: 사고수, dtype: float64

# %%
acc_ele_lunch2.to_csv("C:/Users/MYCOM/data/acc_ele_lunch2.csv")

# %%
sns.heatmap(acc_ele_lunch2.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 안전교육 시간 - 초등학교 전체

# %%
data5=pd.read_excel("C:/Users/MYCOM/data/2022년_안전교육 계획 및 실시 현황(초)_전체.xlsx")
data5.head()
# Out:
#       시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드  \
# 0     시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드
# 1     시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드
# 2  서울특별시교육청             교육부  서울특별시 서초구    S000003511    서울교육대학교부설초등학교     02
# 3  서울특별시교육청             교육부  서울특별시 종로구    S000003563  서울대학교사범대학부설초등학교     02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구    S010000738         서울개일초등학교     02
#
#    설립구분  제외여부  제외사유  전체학급수  ... 약물 및 사이버 중독 예방 교육 \n 시간(단위활동 차시).5  \
# 0  설립구분  제외여부  제외사유  전체학급수  ...        사이버 중독 예방 교육 \n 시간(단위활동 차시)
# 1  설립구분  제외여부  제외사유  전체학급수  ...                     사이버중독예방교육시간 합계
# 2    국립     N   NaN   27.0  ...                                6.0
# 3    국립     N   NaN   30.0  ...                                4.0
# 4    공립     N   NaN   32.0  ...                                5.0
#
#    재난안전 교육 \n 시간(단위활동 차시) 재난안전 교육 \n 시간(단위활동 차시).1 재난안전 교육 \n 시간(단위활동 차시).2  \
# ...

# %%
# 두번 돌리기
data5.set_axis(data5.iloc[0], axis=1, inplace=True)
data5 = data5[1:]
data5.head()
# Out:
# 1     시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명 학교급코드  \
# 2  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교    02
# 3  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교    02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교    02
# 5  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교    02
# 6  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교    02
#
# 1 설립구분 제외여부 제외사유 전체학급수  ... 사이버중독예방교육시간 합계  1학기  2학기 재난안전교육시간 합계  1학기  2학기  \
# 2   국립    N  NaN  27.0  ...            6.0  3.0  3.0         6.0  1.0  1.0
# 3   국립    N  NaN  30.0  ...            4.0  2.0  2.0         4.0  2.0  2.0
# 4   공립    N  NaN  32.0  ...            5.0  4.0  2.0         6.0  1.0  1.0
# 5   공립    N  NaN  30.0  ...            3.2  3.0  3.3         6.3  3.0  3.0
# 6   공립    N  NaN  14.0  ...            5.0  3.0  3.0         6.0  1.0  1.0
#
# 1 직업안전교육시간 합계  1학기  2학기 응급처치교육시간 합계
# ...

# %%
data5.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 \n 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '전체학급수', '전체학생수', '1학기', '2학기', '생활안전교육시간 합계', '1학기', '2학기',
#        '교통안전교육시간 합계', '1학기', '2학기', '폭력예방및신변보호교육시간 합계', '1학기', '2학기',
#        '약물중독예방교육시간 합계', '1학기', '2학기', '사이버중독예방교육시간 합계', '1학기', '2학기',
#        '재난안전교육시간 합계', '1학기', '2학기', '직업안전교육시간 합계', '1학기', '2학기',
#        '응급처치교육시간 합계'],
#       dtype='object', name=1)

# %%
data5=data5[['시도교육청','지역','학교명','전체학급수','전체학생수','생활안전교육시간 합계','교통안전교육시간 합계',
             '폭력예방및신변보호교육시간 합계','약물중독예방교육시간 합계','사이버중독예방교육시간 합계','재난안전교육시간 합계',
            '직업안전교육시간 합계','응급처치교육시간 합계']]

# %%
data5.dropna(inplace=True)
data5.isnull().sum()
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6260 entries, 2 to 6310
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도교육청             6260 non-null   object
#  1   지역                6260 non-null   object
#  2   학교명               6260 non-null   object
#  3   전체학급수             6260 non-null   object
#  4   전체학생수             6260 non-null   object
#  5   생활안전교육시간 합계       6260 non-null   object
#  6   교통안전교육시간 합계       6260 non-null   object
#  7   폭력예방및신변보호교육시간 합계  6260 non-null   object
#  8   약물중독예방교육시간 합계     6260 non-null   object
#  9   사이버중독예방교육시간 합계    6260 non-null   object
#  10  재난안전교육시간 합계       6260 non-null   object
#  11  직업안전교육시간 합계       6260 non-null   object
#  12  응급처치교육시간 합계       6260 non-null   object
# dtypes: object(13)
# memory usage: 684.7+ KB

# %%
data5.columns
# Out:
# Index(['시도교육청', '지역', '학교명', '전체학급수', '전체학생수', '생활안전교육시간 합계', '교통안전교육시간 합계',
#        '폭력예방및신변보호교육시간 합계', '약물중독예방교육시간 합계', '사이버중독예방교육시간 합계', '재난안전교육시간 합계',
#        '직업안전교육시간 합계', '응급처치교육시간 합계'],
#       dtype='object', name=1)

# %%
data5[['전체학급수', '전체학생수', '생활안전교육시간 합계', '교통안전교육시간 합계',
       '폭력예방및신변보호교육시간 합계', '약물중독예방교육시간 합계', '사이버중독예방교육시간 합계', '재난안전교육시간 합계',
       '직업안전교육시간 합계', '응급처치교육시간 합계']]=data5[['전체학급수', '전체학생수', '생활안전교육시간 합계', '교통안전교육시간 합계',
       '폭력예방및신변보호교육시간 합계', '약물중독예방교육시간 합계', '사이버중독예방교육시간 합계', '재난안전교육시간 합계',
       '직업안전교육시간 합계', '응급처치교육시간 합계']].astype(float)
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6260 entries, 2 to 6310
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   시도교육청             6260 non-null   object
#  1   지역                6260 non-null   object
#  2   학교명               6260 non-null   object
#  3   전체학급수             6260 non-null   float64
#  4   전체학생수             6260 non-null   float64
#  5   생활안전교육시간 합계       6260 non-null   float64
#  6   교통안전교육시간 합계       6260 non-null   float64
#  7   폭력예방및신변보호교육시간 합계  6260 non-null   float64
#  8   약물중독예방교육시간 합계     6260 non-null   float64
#  9   사이버중독예방교육시간 합계    6260 non-null   float64
#  10  재난안전교육시간 합계       6260 non-null   float64
#  11  직업안전교육시간 합계       6260 non-null   float64
#  12  응급처치교육시간 합계       6260 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 684.7+ KB

# %%
data5['학급당 평균 학생수']=round(data5['전체학생수']/data5['전체학급수'],2)
data5.head()
# Out:
# 1     시도교육청         지역              학교명  전체학급수   전체학생수  생활안전교육시간 합계  \
# 2  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   27.0   606.0         12.0
# 3  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   30.0   617.0          4.0
# 4  서울특별시교육청  서울특별시 강남구         서울개일초등학교   32.0  1004.0         12.0
# 5  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   30.0   726.0         11.0
# 6  서울특별시교육청  서울특별시 강남구         서울논현초등학교   14.0   281.0         12.0
#
# 1  교통안전교육시간 합계  폭력예방및신변보호교육시간 합계  약물중독예방교육시간 합계  사이버중독예방교육시간 합계  재난안전교육시간 합계  \
# 2         11.0               8.0           10.0             6.0          6.0
# 3          4.0               4.0            4.0             4.0          4.0
# 4         11.0               8.0            5.0             5.0          6.0
# 5         10.0               5.5            2.0             3.2          6.3
# 6         11.0               8.0            5.0             5.0          6.0
#
# 1  직업안전교육시간 합계  응급처치교육시간 합계  학급당 평균 학생수
# 2          2.0          2.0       22.44
# ...

# %% [markdown]
# # 전체 안전교육 & 사고수 합치기

# %%
acc_ele_safety2 = pd.merge(data5,acc_ele2, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_safety2['사고수'] = acc_ele_safety2['사고수'].fillna(0)
acc_ele_safety2.head()
# Out:
#       시도교육청         지역              학교명  전체학급수   전체학생수  생활안전교육시간 합계  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   27.0   606.0         12.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   30.0   617.0          4.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교   32.0  1004.0         12.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   30.0   726.0         11.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교   14.0   281.0         12.0
#
#    교통안전교육시간 합계  폭력예방및신변보호교육시간 합계  약물중독예방교육시간 합계  사이버중독예방교육시간 합계  재난안전교육시간 합계  \
# 0         11.0               8.0           10.0             6.0          6.0
# 1          4.0               4.0            4.0             4.0          4.0
# 2         11.0               8.0            5.0             5.0          6.0
# 3         10.0               5.5            2.0             3.2          6.3
# 4         11.0               8.0            5.0             5.0          6.0
#
#    직업안전교육시간 합계  응급처치교육시간 합계  학급당 평균 학생수   사고수
# 0          2.0          2.0       22.44  36.0
# ...

# %%
acc_ele_safety2.corr()['사고수']
# Out:
# 전체학급수               0.388482
# 전체학생수               0.393565
# 생활안전교육시간 합계        -0.003603
# 교통안전교육시간 합계        -0.005736
# 폭력예방및신변보호교육시간 합계   -0.011806
# 약물중독예방교육시간 합계      -0.019328
# 사이버중독예방교육시간 합계     -0.022375
# 재난안전교육시간 합계        -0.006415
# 직업안전교육시간 합계        -0.026958
# 응급처치교육시간 합계        -0.019844
# 학급당 평균 학생수          0.342329
# 사고수                 1.000000
# Name: 사고수, dtype: float64

# %%
acc_ele_safety2.shape
# Out:
# (6383, 15)

# %%
acc_ele_safety2.to_csv("C:/Users/MYCOM/data/acc_ele_safety2.csv")

# %%
sns.heatmap(acc_ele_safety2.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 방과후 전체

# %%
data6=pd.read_excel("C:/Users/MYCOM/data/2022년_ 방과후학교 운영계획 및 운영ㆍ지원현황(초)_전체.xlsx")
data6.head()
# Out:
# C:\Users\MYCOM\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명  학교급코드  \
# 0  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교      2
# 1  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교      2
# 2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교      2
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교      2
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교      2
#
#   설립구분 제외여부 제외사유  교과 프로그램수  ...  초등돌봄교실 \n 저녁돌봄 참여학생수  \
# 0   국립    N  NaN       4.0  ...                   9.0
# 1   국립    N  NaN      25.0  ...                   0.0
# 2   공립    N  NaN       6.0  ...                   0.0
# 3   공립    N  NaN      10.0  ...                   0.0
# ...

# %%
data6.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 \n 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '교과 프로그램수', '교과 수강학생수', '특기적성 프로그램수', '특기적성 수강학생수', '프로그램수(계)',
#        '수강학생수(계)', '방과후학교참여학생수', '초등돌봄교실 \n 오후돌봄 운영교실수',
#        '초등돌봄교실 \n 오후돌봄 참여학생수', '초등돌봄교실 \n 저녁돌봄 운영교실수', '초등돌봄교실 \n 저녁돌봄 참여학생수',
#        '초등돌봄교실 방과후학교 \n 연계형 돌봄 운영교실수', '초등돌봄교실 방과후학교 \n 연계형 돌봄 참여학생수',
#        '초등돌봄참여학생중 \n 특수교육대상학생수', '특수학교종일반 \n 학급수', '특수학교종일반 \n 참여학생수',
#        '방과후학교 \n 수익자부담금액', '방과후학교 \n 수익자부담외지원금액', '초등돌봄교실 \n 수익자부담금액',
#        '초등돌봄교실 \n 수익자부담외지원금액'],
#       dtype='object')

# %%
data6=data6[['시도교육청','지역','학교명','교과 프로그램수', '교과 수강학생수', '특기적성 프로그램수', '특기적성 수강학생수', '프로그램수(계)',
       '수강학생수(계)', '방과후학교참여학생수', '초등돌봄교실 \n 오후돌봄 운영교실수',
       '초등돌봄교실 \n 오후돌봄 참여학생수', '초등돌봄교실 \n 저녁돌봄 운영교실수', '초등돌봄교실 \n 저녁돌봄 참여학생수',
       '초등돌봄교실 방과후학교 \n 연계형 돌봄 운영교실수', '초등돌봄교실 방과후학교 \n 연계형 돌봄 참여학생수']]
data6.isnull().sum()
# Out:
# 시도교육청                           0
# 지역                              5
# 학교명                             0
# 교과 프로그램수                        0
# 교과 수강학생수                        0
# 특기적성 프로그램수                      0
# 특기적성 수강학생수                      0
# 프로그램수(계)                        0
# 수강학생수(계)                        0
# 방과후학교참여학생수                      0
# 초등돌봄교실 \n 오후돌봄 운영교실수            0
# 초등돌봄교실 \n 오후돌봄 참여학생수            0
# 초등돌봄교실 \n 저녁돌봄 운영교실수            0
# 초등돌봄교실 \n 저녁돌봄 참여학생수            0
# 초등돌봄교실 방과후학교 \n 연계형 돌봄 운영교실수    0
# 초등돌봄교실 방과후학교 \n 연계형 돌봄 참여학생수    0
# dtype: int64

# %%
data6.dropna(inplace=True)
data6.head()
# Out:
#       시도교육청         지역              학교명  교과 프로그램수  교과 수강학생수  특기적성 프로그램수  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교       4.0      51.0         8.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교      25.0     255.0        27.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교       6.0      62.0        38.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교      10.0     126.0        42.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교       7.0     133.0        13.0
#
#    특기적성 수강학생수  프로그램수(계)  수강학생수(계)  방과후학교참여학생수  초등돌봄교실 \n 오후돌봄 운영교실수  \
# 0       112.0      12.0     163.0       163.0                   1.0
# 1       303.0      52.0     558.0       301.0                   0.0
# 2       484.0      44.0     546.0       257.0                   2.0
# 3       601.0      52.0     727.0       359.0                   4.0
# 4       386.0      20.0     519.0       175.0                   4.0
#
#    초등돌봄교실 \n 오후돌봄 참여학생수  초등돌봄교실 \n 저녁돌봄 운영교실수  초등돌봄교실 \n 저녁돌봄 참여학생수  \
# ...

# %% [markdown]
# # 전체 사고수 & 방과후 데이터 합치기

# %%
acc_ele_after2 = pd.merge(data6,acc_ele2, left_on=('학교명'), right_on=('학교명'), how='outer')
acc_ele_after2['사고수'] = acc_ele_after2['사고수'].fillna(0)
acc_ele_after2.head()
# Out:
#       시도교육청         지역              학교명  교과 프로그램수  교과 수강학생수  특기적성 프로그램수  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교       4.0      51.0         8.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교      25.0     255.0        27.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교       6.0      62.0        38.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교      10.0     126.0        42.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교       7.0     133.0        13.0
#
#    특기적성 수강학생수  프로그램수(계)  수강학생수(계)  방과후학교참여학생수  초등돌봄교실 \n 오후돌봄 운영교실수  \
# 0       112.0      12.0     163.0       163.0                   1.0
# 1       303.0      52.0     558.0       301.0                   0.0
# 2       484.0      44.0     546.0       257.0                   2.0
# 3       601.0      52.0     727.0       359.0                   4.0
# 4       386.0      20.0     519.0       175.0                   4.0
#
#    초등돌봄교실 \n 오후돌봄 참여학생수  초등돌봄교실 \n 저녁돌봄 운영교실수  초등돌봄교실 \n 저녁돌봄 참여학생수  \
# ...

# %%
acc_ele_after2.corr()['사고수']
# Out:
# 교과 프로그램수                        0.197153
# 교과 수강학생수                        0.225758
# 특기적성 프로그램수                      0.271906
# 특기적성 수강학생수                      0.334775
# 프로그램수(계)                        0.277460
# 수강학생수(계)                        0.343557
# 방과후학교참여학생수                      0.356346
# 초등돌봄교실 \n 오후돌봄 운영교실수            0.266539
# 초등돌봄교실 \n 오후돌봄 참여학생수            0.295148
# 초등돌봄교실 \n 저녁돌봄 운영교실수            0.026597
# 초등돌봄교실 \n 저녁돌봄 참여학생수            0.024554
# 초등돌봄교실 방과후학교 \n 연계형 돌봄 운영교실수   -0.001839
# 초등돌봄교실 방과후학교 \n 연계형 돌봄 참여학생수    0.028177
# 사고수                             1.000000
# Name: 사고수, dtype: float64

# %%
acc_ele_after2.to_csv("C:/Users/MYCOM/data/acc_ele_after2.csv")

# %%
sns.heatmap(acc_ele_after2.corr())
# Out:
# <AxesSubplot:>

# %%
acc_ele_safety3=acc_ele_safety2[acc_ele_safety2['시도교육청'].isin(['경기도교육청','서울특별시교육청'])]
acc_ele_safety3['나라']='대한민국'
# '주소' 열 삭제 (원본 DataFrame에서 제거)
acc_ele_safety3.head()
# Out:
# C:\Users\MYCOM\AppData\Local\Temp\ipykernel_23412\3225816893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acc_ele_safety3['나라']='대한민국'
#       시도교육청         지역              학교명  전체학급수   전체학생수  생활안전교육시간 합계  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   27.0   606.0         12.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   30.0   617.0          4.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교   32.0  1004.0         12.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   30.0   726.0         11.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교   14.0   281.0         12.0
#
#    교통안전교육시간 합계  폭력예방및신변보호교육시간 합계  약물중독예방교육시간 합계  사이버중독예방교육시간 합계  재난안전교육시간 합계  \
# 0         11.0               8.0           10.0             6.0          6.0
# ...

# %%
acc_ele_safety3=pd.read_excel("C:/Users/MYCOM/data/acc_ele_safety3.xlsx")
acc_ele_safety3.head()
# Out:
#    Unnamed: 0     시도교육청         지역              학교명  전체학급수  전체학생수  \
# 0           0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교     27    606
# 1           1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교     30    617
# 2           2  서울특별시교육청  서울특별시 강남구         서울개일초등학교     32   1004
# 3           3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교     30    726
# 4           4  서울특별시교육청  서울특별시 강남구         서울논현초등학교     14    281
#
#    생활안전교육시간 합계  교통안전교육시간 합계  폭력예방및신변보호교육시간 합계  약물중독예방교육시간 합계  사이버중독예방교육시간 합계  \
# 0         12.0         11.0               8.0           10.0             6.0
# 1          4.0          4.0               4.0            4.0             4.0
# 2         12.0         11.0               8.0            5.0             5.0
# 3         11.0         10.0               5.5            2.0             3.2
# 4         12.0         11.0               8.0            5.0             5.0
#
#    재난안전교육시간 합계  직업안전교육시간 합계  응급처치교육시간 합계  학급당 평균 학생수  사고수    나라      도    시
# ...

# %%
acc_ele_safety3['지역'].value_counts()
# Out:
# 경기도 용인시       103
# 경기도 화성시       103
# 경기도 수원시        99
# 경기도 고양시        88
# 경기도 성남시        72
# 경기도 남양주시       66
# 경기도 평택시        65
# 경기도 부천시        64
# 경기도 파주시        58
# 경기도 안산시        55
# 경기도 시흥시        48
# 경기도 김포시        47
# 서울특별시 노원구      42
# 서울특별시 송파구      40
# 경기도 안양시        40
# 경기도 양주시        36
# 경기도 안성시        35
# 서울특별시 강서구      35
# 경기도 의정부시       34
# 경기도 이천시        31
# 서울특별시 강남구      31
# 서울특별시 은평구      30
# 서울특별시 양천구      30
# 서울특별시 성북구      29
# 경기도 광주시        29
# 경기도 포천시        28
# 경기도 군포시        27
# 서울특별시 강동구      27
# 서울특별시 구로구      26
# 경기도 오산시        25
# 경기도 광명시        24
# 서울특별시 서초구      24
# 경기도 여주시        24
# 서울특별시 도봉구      23
# 경기도 하남시        23
# 서울특별시 영등포구     23
# 서울특별시 중랑구      23
# 경기도 양평군        23
# 서울특별시 관악구      22
# 서울특별시 마포구      22
# 서울특별시 광진구      22
# 서울특별시 동작구      21
# 서울특별시 동대문구     21
# 서울특별시 성동구      21
# 서울특별시 서대문구     19
# 서울특별시 금천구      18
# 경기도 가평군        16
# 경기도 구리시        16
# 서울특별시 용산구      15
# 서울특별시 강북구      14
# ...

# %%
acc_ele_safety3['도'] = ''
acc_ele_safety3['시'] = ''
acc_ele_safety3[['도','시']]=acc_ele_safety3['지역'].str.split(' ',1,expand=True)

# %%
acc_ele_safety3['시'].value_counts()
# Out:
# 용인시     103
# 화성시     103
# 수원시      99
# 고양시      88
# 성남시      72
# 남양주시     66
# 평택시      65
# 부천시      64
# 파주시      58
# 안산시      55
# 시흥시      48
# 김포시      47
# 노원구      42
# 송파구      40
# 안양시      40
# 양주시      36
# 안성시      35
# 강서구      35
# 의정부시     34
# 이천시      31
# 강남구      31
# 은평구      30
# 양천구      30
# 성북구      29
# 광주시      29
# 포천시      28
# 군포시      27
# 강동구      27
# 구로구      26
# 오산시      25
# 광명시      24
# 서초구      24
# 여주시      24
# 도봉구      23
# 하남시      23
# 영등포구     23
# 중랑구      23
# 양평군      23
# 관악구      22
# 마포구      22
# 광진구      22
# 동작구      21
# 동대문구     21
# 성동구      21
# 서대문구     19
# 금천구      18
# 가평군      16
# 구리시      16
# 용산구      15
# 강북구      14
# 의왕시      14
# 종로구      13
# 연천군      13
# 중구       12
# 동두천시     11
# 과천시       4
# Name: 시, dtype: int64

# %%
acc_ele_safety3.to_excel("C:/Users/MYCOM/data/acc_ele_safety3.xlsx")

# %%
acc_ele_safety3.head(5)

# %%
acc_ele_after2.head()

# %%
acc_ele_lunch2.head()

# %%
acc_ele_lunch3=acc_ele_lunch2.drop(['시도교육청','지역','사고수'],axis=1,inplace=False)
acc_ele_after3=acc_ele_after2.drop(['시도교육청','지역','사고수'],axis=1,inplace=False)
acc_ele_total=pd.merge(acc_ele_safety3,acc_ele_after3,on='학교명',how='outer')
acc_ele_total=pd.merge(acc_ele_total,acc_ele_lunch3,on='학교명',how='outer')
acc_ele_total.head()

# %%
acc_ele_total.columns

# %%
acc_ele_total.to_excel("C:/Users/MYCOM/data/acc_ele_total.xlsx")

# %% [markdown]
# # 환경위생관리 점수

# %%
data7=pd.read_excel("C:/Users/MYCOM/data/2022년_환경위생관리 현황(초)_전체.xlsx")
data7.head()
# Out:
#       시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드  \
# 0     시도교육청           지역교육청         지역  정보공시 \n 학교코드              학교명  학교급코드
# 1  서울특별시교육청             교육부  서울특별시 서초구    S000003511    서울교육대학교부설초등학교     02
# 2  서울특별시교육청             교육부  서울특별시 종로구    S000003563  서울대학교사범대학부설초등학교     02
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구    S010000738         서울개일초등학교     02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구    S010000741         서울구룡초등학교     02
#
#    설립구분  제외여부  상하반기구분        자연환기  ... 벤젠  30(㎍/㎥)이하 톨루엔 1000(㎍/㎥)이하  \
# 0  설립구분  제외여부  상하반기구분  자연환기 적합 여부  ...      벤젠 적합 여부       톨루엔 적합 여부
# 1    국립     N     상반기          실시  ...             0               0
# 2    국립     N     상반기          실시  ...             1               1
# 3    공립     N     상반기          실시  ...             0               0
# 4    공립     N     상반기          실시  ...             1               1
#
#   에틸벤젠 360(㎍/㎥)이하 자이렌 700(㎍/㎥)이하 스티렌 300(㎍/㎥)이하 석면 0.01(개/cc)이하  \
# ...

# %%
data7.set_axis(data7.iloc[0], axis=1, inplace=True)
data7 = data7[1:]
data7.head()
# Out:
# 0     시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명 학교급코드  \
# 1  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교    02
# 2  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교    02
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교    02
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교    02
# 5  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교    02
#
# 0 설립구분 제외여부 상하반기구분 자연환기 적합 여부  ... 벤젠 적합 여부 톨루엔 적합 여부 에틸벤젠 적합 여부 자이렌 적합 여부  \
# 1   국립    N    상반기         실시  ...        0         0          0         0
# 2   국립    N    상반기         실시  ...        1         1          1         1
# 3   공립    N    상반기         실시  ...        0         0          0         0
# 4   공립    N    상반기         실시  ...        1         1          1         1
# 5   공립    N    상반기         실시  ...        0         0          0         0
#
# ...

# %%
pd.set_option('display.max_columns', None)

# 데이터프레임의 컬럼명 확인
data7.columns

# %%
df

# %%
import pandas as pd
data=pd.read_excel("C:/Users/MYCOM/data/2022년_보건관리 현황(초)_전체.xlsx")
data.head()

# %%
data['시도교육청'].value_counts()

# %%
data=data[data['시도교육청'].isin(['경기도교육청','서울특별시교육청'])]
data.shape

# %%
data.head()

# %%
data['지역'].value_counts()

# %%
df=data['지역'].str.split(' ')

# %%
df[100:]

# %%
data.reset_index(inplace=True)

# %%
data['나라']='대한민국'

# %%
data[['시','구']]=data['지역'].str.split(' ',1,expand=True)
data.head()
# Out:
#    index     시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명  \
# 0      0  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교
# 1      1  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교
# 2      2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교
# 3      3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교
# 4      4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교
#
#    학교급코드 설립구분 제외여부 제외사유  연간보건실 \n 이용건수  전체 학생수  연간 1인당 \n 보건실 이용건수    나라  \
# 0      2   국립    N  NaN         4503.0   611.0                 7.4  대한민국
# 1      2   국립    N  NaN         2133.0   621.0                 3.4  대한민국
# 2      2   공립    N  NaN         5616.0  1004.0                 5.6  대한민국
# 3      2   공립    N  NaN         4128.0   733.0                 5.6  대한민국
# 4      2   공립    N  NaN         1013.0   290.0                 3.5  대한민국
#
#          (시, 구)      시    구
# 0  [서울특별시, 서초구]  서울특별시  서초구
# ...

# %%
data.columns
# Out:
# Index([             'index',              '시도교육청',              '지역교육청',
#                        '지역',       '정보공시 \n 학교코드',                '학교명',
#                     '학교급코드',               '설립구분',               '제외여부',
#                      '제외사유',      '연간보건실 \n 이용건수',             '전체 학생수',
#        '연간 1인당 \n 보건실 이용건수',                 '나라',           ('시', '구'),
#                         '시',                  '구'],
#       dtype='object')

# %%
data = data.drop('index', axis=1)

# "('시', '구')" 컬럼 삭제
data = data.drop(('시', '구'), axis=1)
data.head()
# Out:
#       시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명  학교급코드  \
# 0  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교      2
# 1  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교      2
# 2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교      2
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교      2
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000742         서울논현초등학교      2
#
#   설립구분 제외여부 제외사유  연간보건실 \n 이용건수  전체 학생수  연간 1인당 \n 보건실 이용건수    나라      시    구
# 0   국립    N  NaN         4503.0   611.0                 7.4  대한민국  서울특별시  서초구
# 1   국립    N  NaN         2133.0   621.0                 3.4  대한민국  서울특별시  종로구
# 2   공립    N  NaN         5616.0  1004.0                 5.6  대한민국  서울특별시  강남구
# 3   공립    N  NaN         4128.0   733.0                 5.6  대한민국  서울특별시  강남구
# 4   공립    N  NaN         1013.0   290.0                 3.5  대한민국  서울특별시  강남구

# %%
data.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 \n 학교코드', '학교명', '학교급코드', '설립구분', '제외여부',
#        '제외사유', '연간보건실 \n 이용건수', '전체 학생수', '연간 1인당 \n 보건실 이용건수', '나라', '시',
#        '구'],
#       dtype='object')

# %%
data=data[['시도교육청','지역','학교명','연간보건실 \n 이용건수', '전체 학생수', '연간 1인당 \n 보건실 이용건수', '나라', '시',
       '구']]
data.head()
# Out:
#       시도교육청         지역              학교명  연간보건실 \n 이용건수  전체 학생수  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교         4503.0   611.0
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교         2133.0   621.0
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교         5616.0  1004.0
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교         4128.0   733.0
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교         1013.0   290.0
#
#    연간 1인당 \n 보건실 이용건수    나라      시    구
# 0                 7.4  대한민국  서울특별시  서초구
# 1                 3.4  대한민국  서울특별시  종로구
# 2                 5.6  대한민국  서울특별시  강남구
# 3                 5.6  대한민국  서울특별시  강남구
# 4                 3.5  대한민국  서울특별시  강남구

# %%
data.isnull().sum()
# Out:
# 시도교육청                  0
# 지역                    10
# 학교명                    0
# 연간보건실 \n 이용건수          1
# 전체 학생수                 1
# 연간 1인당 \n 보건실 이용건수     0
# 나라                     0
# 시                     10
# 구                     10
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# 시도교육청                 0
# 지역                    0
# 학교명                   0
# 연간보건실 \n 이용건수         0
# 전체 학생수                0
# 연간 1인당 \n 보건실 이용건수    0
# 나라                    0
# 시                     0
# 구                     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['시도교육청', '지역', '학교명', '연간보건실 \n 이용건수', '전체 학생수', '연간 1인당 \n 보건실 이용건수',
#        '나라', '시', '구'],
#       dtype='object')

# %%
new_col=['시도교육청','지역','학교명','연간 보건실 이용건수','전체 학생수','연간 1인당 보건실 이용건수','나라','시','구']
data.columns=new_col
data.head()
# Out:
#       시도교육청         지역              학교명  연간 보건실 이용건수  전체 학생수  연간 1인당 보건실 이용건수  \
# 0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교       4503.0   611.0              7.4
# 1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교       2133.0   621.0              3.4
# 2  서울특별시교육청  서울특별시 강남구         서울개일초등학교       5616.0  1004.0              5.6
# 3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교       4128.0   733.0              5.6
# 4  서울특별시교육청  서울특별시 강남구         서울논현초등학교       1013.0   290.0              3.5
#
#      나라      시    구
# 0  대한민국  서울특별시  서초구
# 1  대한민국  서울특별시  종로구
# 2  대한민국  서울특별시  강남구
# 3  대한민국  서울특별시  강남구
# 4  대한민국  서울특별시  강남구

# %%
data.to_excel("C:/Users/MYCOM/data/초등학교_보건실_서울경기.xlsx")

# %%
acc_ele_safety2=pd.read_csv("C:/Users/MYCOM/data/acc_ele_safety2.csv")

# %%
acc_ele_safety2.drop('Unnamed: 0',axis=1,inplace=True)

# %%
acc_ele_safety_corr=pd.DataFrame(acc_ele_safety2.corr()['사고수'])

# %%
acc_ele_safety_corr.to_excel("C:/Users/MYCOM/data/acc_ele_safety_corr.xlsx")

# %%
acc_ele_after2=pd.read_csv("C:/Users/MYCOM/data/acc_ele_after2.csv")
acc_ele_after2.drop('Unnamed: 0',axis=1,inplace=True)
acc_ele_after_corr=pd.DataFrame(acc_ele_after2.corr()['사고수'])
acc_ele_after_corr.to_excel("C:/Users/MYCOM/data/acc_ele_after_corr.xlsx")

# %%
acc_ele_lunch2=pd.read_csv("C:/Users/MYCOM/data/acc_ele_lunch2.csv")
acc_ele_lunch2.head()
# Out:
#    Unnamed: 0     시도교육청         지역              학교명  전체 학생수  급식 학생수   급식비율  \
# 0           0  서울특별시교육청  서울특별시 서초구    서울교육대학교부설초등학교   612.0   612.0  100.0
# 1           1  서울특별시교육청  서울특별시 종로구  서울대학교사범대학부설초등학교   613.0   612.0   99.8
# 2           2  서울특별시교육청  서울특별시 강남구         서울개일초등학교  1078.0   780.0   72.4
# 3           3  서울특별시교육청  서울특별시 강남구         서울구룡초등학교   745.0   745.0  100.0
# 4           4  서울특별시교육청  서울특별시 강남구         서울논현초등학교   266.0   266.0  100.0
#
#    영양(교)사  조리사  조리원  배식장소(식당)  배식장소(교실)   사고수
# 0     1.0  1.0  3.0       1.0       0.0  36.0
# 1     1.0  1.0  4.0       1.0       1.0  21.0
# 2     1.0  1.0  5.0       1.0       0.0  18.0
# 3     1.0  1.0  4.0       1.0       0.0  33.0
# 4     1.0  1.0  3.0       1.0       0.0   6.0

# %%
acc_ele_lunch2.drop('Unnamed: 0',axis=1,inplace=True)
acc_ele_lunch_corr=pd.DataFrame(acc_ele_lunch2.corr()['사고수'])
acc_ele_lunch_corr.to_excel("C:/Users/MYCOM/data/acc_ele_lunch_corr.xlsx")
